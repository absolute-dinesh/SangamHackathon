# %%
import pandas as pd

df_test = pd.read_csv("../Data/Test.csv")

df_train = pd.read_csv("../Data/Train.csv")

# %%
weather_description_list = df_train['weather_description'].unique().tolist()
weather_description_list
# Out:
# ['scattered clouds',
#  'broken clouds',
#  'overcast clouds',
#  'sky is clear',
#  'few clouds',
#  'light rain',
#  'light intensity drizzle',
#  'mist',
#  'haze',
#  'fog',
#  'proximity shower rain',
#  'drizzle',
#  'moderate rain',
#  'heavy intensity rain',
#  'proximity thunderstorm',
#  'thunderstorm with light rain',
#  'proximity thunderstorm with rain',
#  'heavy snow',
#  'heavy intensity drizzle',
#  'snow',
#  'thunderstorm with heavy rain',
#  'freezing rain',
#  'shower snow',
#  'light rain and snow',
#  'light intensity shower rain',
#  'SQUALLS',
#  'thunderstorm with rain',
#  'proximity thunderstorm with drizzle',
#  'thunderstorm',
#  'Sky is Clear',
#  'very heavy rain',
#  'thunderstorm with light drizzle',
#  'light snow',
#  'thunderstorm with drizzle',
#  'smoke',
#  'shower drizzle',
#  'light shower snow',
#  'sleet']

# %%
#import pandas as pd

#df_test = pd.read_csv("../Data/Test.csv")

#df_train = pd.read_csv("../Data/Train.csv")

#weather_description_list = df_train['weather_description'].unique().tolist()
#weather_description_list
#weather_description_dic = {}
#j = 0
#for i in weather_description_list:
#    weather_description_dic[i] = j
#    j = j+1

#for i in range(len(df_train)):
#    df_train['weather_description'].loc[i] = weather_description_dic[df_train['weather_description'].loc[i]]

# %%
df_train['weather_description'] = df_train['weather_description'].astype('category')
print(df_train['weather_description'].unique())
df_train['weather_description'] = df_train['weather_description'].cat.codes
# Out:
# [scattered clouds, broken clouds, overcast clouds, sky is clear, few clouds, ..., thunderstorm with drizzle, smoke, shower drizzle, light shower snow, sleet]
# Length: 38
# Categories (38, object): [scattered clouds, broken clouds, overcast clouds, sky is clear, ..., smoke, shower drizzle, light shower snow, sleet]

# %%
df_train['weather_description'] = df_train['weather_description'].astype('category')
print(df_train['weather_description'].unique())
df_train['weather_description'] = df_train['weather_description'].cat.codes
# Out:
# [scattered clouds, broken clouds, overcast clouds, sky is clear, few clouds, ..., thunderstorm with drizzle, smoke, shower drizzle, light shower snow, sleet]
# Length: 38
# Categories (38, object): [scattered clouds, broken clouds, overcast clouds, sky is clear, ..., smoke, shower drizzle, light shower snow, sleet]

# %%
df_train['weather_type'] = df_train['weather_type'].astype('category')
print(df_train['weather_type'].unique())
df_train['weather_type'] = df_train['weather_type'].cat.codes
# Out:
# [Clouds, Clear, Rain, Drizzle, Mist, ..., Fog, Thunderstorm, Snow, Squall, Smoke]
# Length: 11
# Categories (11, object): [Clouds, Clear, Rain, Drizzle, ..., Thunderstorm, Snow, Squall, Smoke]

# %%
df_train['is_holiday'] = df_train['is_holiday'].astype('category')
print(df_train['is_holiday'].unique())
df_train['is_holiday'] = df_train['is_holiday'].cat.codes
# Out:
# [None, Columbus Day, Veterans Day, Thanksgiving Day, Christmas Day, ..., Memorial Day, Independence Day, State Fair, Labor Day, Martin Luther King Jr Day]
# Length: 12
# Categories (12, object): [None, Columbus Day, Veterans Day, Thanksgiving Day, ..., Independence Day, State Fair, Labor Day, Martin Luther King Jr Day]

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import time
import calendar, time

# %%
df_train
# Out:
#                  date_time  is_holiday  air_pollution_index  humidity  \
# 0      2012-10-02 09:00:00           7                  121        89
# 1      2012-10-02 10:00:00           7                  178        67
# 2      2012-10-02 11:00:00           7                  113        66
# 3      2012-10-02 12:00:00           7                   20        66
# 4      2012-10-02 13:00:00           7                  281        65
# 5      2012-10-02 14:00:00           7                   23        65
# 6      2012-10-02 15:00:00           7                  184        64
# 7      2012-10-02 16:00:00           7                  167        64
# 8      2012-10-02 17:00:00           7                  119        63
# 9      2012-10-02 18:00:00           7                  161        63
# 10     2012-10-02 19:00:00           7                  243        62
# 11     2012-10-02 20:00:00           7                  150        62
# ...

# %%
data = pd.DataFrame()

for index, row in df_train.iterrows():
    timestamp = datetime.strptime(row['date_time'], '%Y-%m-%d %H:%M:%S')
    epoch = int(calendar.timegm(timestamp.utctimetuple()))
    print(epoch)
    data = data.append({'epoch':epoch}, ignore_index=True)
# Out:
# 1349168400
# 1349172000
# 1349175600
# 1349179200
# 1349182800
# 1349186400
# 1349190000
# 1349193600
# 1349197200
# 1349200800
# 1349204400
# 1349208000
# 1349211600
# 1349215200
# 1349218800
# 1349222400
# 1349226000
# 1349229600
# 1349233200
# 1349236800
# 1349240400
# 1349244000
# 1349251200
# 1349254800
# 1349265600
# 1349269200
# 1349272800
# 1349276400
# 1349280000
# 1349287200
# 1349290800
# 1349294400
# 1349298000
# 1349301600
# 1349305200
# 1349308800
# 1349312400
# 1349316000
# 1349319600
# 1349323200
# 1349326800
# 1349330400
# 1349334000
# 1349337600
# 1349341200
# 1349344800
# 1349348400
# 1349352000
# 1349355600
# 1349359200
# 1349362800
# 1349366400
# 1349370000
# 1349373600
# 1349377200
# 1349380800
# 1349384400
# 1349388000
# 1349391600
# 1349395200
# 1349398800
# 1349406000
# 1349413200
# 1349416800
# 1349420400
# 1349424000
# 1349427600
# 1349431200
# 1349434800
# 1349438400
# 1349442000
# 1349445600
# 1349449200
# 1349452800
# 1349456400
# 1349460000
# ...

# %%
df_train['epoch'] = data.epoch

# %%
df_train = df_train.drop('date_time', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-3d9bf534419b> in <module>
# ----> 1 df_train = df_train.drop('date_time', axis=1)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
df_train
# Out:
#        is_holiday  air_pollution_index  humidity  wind_speed  wind_direction  \
# 0               7                  121        89           2             329
# 1               7                  178        67           3             330
# 2               7                  113        66           3             329
# 3               7                   20        66           3             329
# 4               7                  281        65           3             329
# 5               7                   23        65           3             328
# 6               7                  184        64           3             328
# 7               7                  167        64           3             327
# 8               7                  119        63           3             327
# 9               7                  161        63           3             326
# 10              7                  243        62           3             326
# ...

# %%
df_test['weather_description'] = df_test['weather_description'].astype('category')
print(df_test['weather_description'].unique())
df_test['weather_description'] = df_test['weather_description'].cat.codes

df_test['weather_type'] = df_test['weather_type'].astype('category')
print(df_test['weather_type'].unique())
df_test['weather_type'] = df_test['weather_type'].cat.codes

df_test['is_holiday'] = df_test['is_holiday'].astype('category')
print(df_test['is_holiday'].unique())
df_test['is_holiday'] = df_test['is_holiday'].cat.codes

data1 = pd.DataFrame()

for index, row in df_test.iterrows():
    timestamp = datetime.strptime(row['date_time'], '%Y-%m-%d %H:%M:%S')
    epoch = int(calendar.timegm(timestamp.utctimetuple()))
    print(epoch)
    data1 = data1.append({'epoch':epoch}, ignore_index=True)
# Out:
# [moderate rain, mist, light intensity drizzle, heavy intensity rain, drizzle, ..., snow, heavy snow, light shower snow, shower drizzle, sleet]
# Length: 32
# Categories (32, object): [moderate rain, mist, light intensity drizzle, heavy intensity rain, ..., heavy snow, light shower snow, shower drizzle, sleet]
# [Rain, Mist, Drizzle, Clouds, Clear, Haze, Fog, Thunderstorm, Smoke, Snow]
# Categories (10, object): [Rain, Mist, Drizzle, Clouds, ..., Fog, Thunderstorm, Smoke, Snow]
# [None, Memorial Day, Independence Day, State Fair, Labor Day, ..., Thanksgiving Day, Christmas Day, New Years Day, Martin Luther King Jr Day, Washingtons Birthday]
# Length: 12
# Categories (12, object): [None, Memorial Day, Independence Day, State Fair, ..., Christmas Day, New Years Day, Martin Luther King Jr Day, Washingtons Birthday]
# 1495065600
# 1495065600
# 1495065600
# 1495069200
# 1495069200
# 1495072800
# 1495072800
# 1495072800
# 1495076400
# 1495076400
# 1495076400
# 1495080000
# 1495080000
# ...

# %%
df_test['epoch'] = data1.epoch

# %%
df_test = df_test.drop('date_time', axis=1)

# %%
df_train_output = df_train['traffic_volume']

# %%
 df_train = df_train.drop('traffic_volume', axis=1)

# %%
# 1. import
from sklearn.linear_model import LogisticRegression

# 2. instantiate model
logreg = LogisticRegression()

# 3. fit 
logreg.fit(df_train, df_train_output)
# Out:
# /Users/saidineshreddymaluchuru/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/saidineshreddymaluchuru/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
new_pred_class = logreg.predict(df_test)
